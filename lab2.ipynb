# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51593/PDS_B10_1593/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

temps_celsius = np.array([12, 15, 20, 25, 30, 35, 33, 32, 28, 22, 18, 14])
months = np.array(["Jan", "Feb", "Mar", "Apr", "May", "Jun",
                   "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

print("Monthly Temperatures (°C):", temps_celsius)

avg_temp = np.mean(temps_celsius)
hottest_month = months[np.argmax(temps_celsius)]
coldest_month = months[np.argmin(temps_celsius)]

print("\nAverage Temperature (°C):", avg_temp)
print("Hottest Month:", hottest_month, "with", temps_celsius.max(), "°C")
print("Coldest Month:", coldest_month, "with", temps_celsius.min(), "°C")

normalized_temps = (temps_celsius - temps_celsius.min()) / (temps_celsius.max() - temps_celsius.min())
print("\nNormalized Temperatures:", normalized_temps)

above_avg_months = months[temps_celsius > avg_temp]
print("\nMonths above annual average:", above_avg_months)

temps_fahrenheit = temps_celsius * 9/5 + 32
print("\nTemperatures in Fahrenheit:", temps_fahrenheit)

plt.plot(months, temps_celsius, marker='o', label="Celsius")
plt.plot(months, temps_fahrenheit, marker='s', label="Fahrenheit")
plt.axhline(avg_temp, color='r', linestyle="--", label=f"Avg Temp {avg_temp:.2f}°C")
plt.title("Monthly Temperature Trend")
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Monthly Temperatures (°C): [12 15 20 25 30 35 33 32 28 22 18 14]
#
# Average Temperature (°C): 23.666666666666668
# Hottest Month: Jun with 35 °C
# Coldest Month: Jan with 12 °C
#
# Normalized Temperatures: [0.         0.13043478 0.34782609 0.56521739 0.7826087  1.
#  0.91304348 0.86956522 0.69565217 0.43478261 0.26086957 0.08695652]
#
# Months above annual average: ['Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep']
#
# Temperatures in Fahrenheit: [53.6 59.  68.  77.  86.  95.  91.4 89.6 82.4 71.6 64.4 57.2]
